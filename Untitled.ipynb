# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
print("hello")
barony_map = gpd.read_file("/Users/mensab/Documents/GISMapFiles/Baronies_-_OSi_National_Statutory_Boundaries_-_Generalised_20m-shp.zip")
barony_map
# Out:
# hello
#       BY_ID                       ENGLISH                           GAEILGE  \
# 0     39010                   TULLA LOWER              An Tulach Íochtarach
# 1     49008  CARBERY WEST (West Division)  Cairbrigh Thiar (an Roinn Thiar)
# 2    219014                     GLENAHIRY                 Gleann na hUidhre
# 3    179005                        TROUGH                        An Triúcha
# 4     79003               DUNKERRON NORTH               Dún Ciaráin Thuaidh
# ..      ...                           ...                               ...
# 275   69019                       MOYCARN                    Maigh Charnáin
# 276  239013                 ATHLONE SOUTH            Baile Átha Luain Theas
# 277   59006                  RAPHOE NORTH                Ráth Bhoth Thuaidh
# 278   99003                    FASSADININ                Fásach an Deighnín
# 279  119001                   CARRIGALLEN                    Carraig Álainn
#
# ...

# %%
tii_data = gpd.read_file("zip:////Users/mensab/Documents/GISMapFiles/TIIArchaeology.zip")
tii_data
# Out:
#      dc_identif                                          url  \
# 0       00E0810  https://repository.dri.ie/catalog/0000cd770
# 1       03E0158  https://repository.dri.ie/catalog/0000cd788
# 2         E3047  https://repository.dri.ie/catalog/0000cd79j
# 3         E3187  https://repository.dri.ie/catalog/0000cd809
# 4       02E1145  https://repository.dri.ie/catalog/0000cd81k
# ...         ...                                          ...
# 1625    02E1144  https://repository.dri.ie/catalog/zs269q242
# 1626      E2440  https://repository.dri.ie/catalog/zs269q25b
# 1627      E3874  https://repository.dri.ie/catalog/zs269q26m
# 1628    03E1458  https://repository.dri.ie/catalog/zs269q331
# 1629    03E1459  https://repository.dri.ie/catalog/zw13bm17w
#
#               Townland                                           dc_title  \
# 0           Sheephouse  Archaeological excavation report, 00E0810 Shee...
# 1             Balregan  Archaeological excavation report, 03E0158 Site...
# ...
